# %%
total=0
total =total+1
print (total)
# Out:
# 1

# %%
total = 0

# range(1, 11) 會產生從 1 到 10 的數字序列
for i in range(1,101):
    total += i

print('1 加到 10 的總和為:', total)
# Out:
# 1 加到 10 的總和為: 5050

# %%
total = 0  # 用來儲存總和
i = 1      # 從 1 開始加

while i <= 10:
    total += i  # 把 i 加到 total 裡面
    i += 1      # i 加 1，避免無限迴圈

print("1加到10的總和為：", total)
# Out:
# 1加到10的總和為： 55

# %%
# 應用：印出 1 到 5 的數字
for i in range(1, 6):
    print(i)

# 應用：走訪串列中的水果名稱
fruits = ["apple", "banana", "cherry"]
for f in fruits:
    print(f)
# Out:
# 1
# 2
# 3
# 4
# 5
# apple
# banana
# cherry

# %%
import random
min = 1
max = 100
count = 0
target = random.randint(1, 100)
print(target)
print("===============猜數字遊戲=================:\n")
while(True):
    count += 1
    keyin = int(input("猜數字範圍{0}~{1}: ".format(min, max)))
    if(keyin >=min and keyin <= max):
        if(keyin == target):
            print("賓果!猜對了, 答案是:", target)
            print("您猜了",count,"次")
            break
        elif (keyin > target):
            max = keyin
            print("再小一點")
        elif (keyin < target):
            min = keyin
            print("再大一點")
        print("您猜了",count,"次\n")
    else:
        print("請輸入提示範圍內的數字")
print("遊戲結束")
# Out:
# 19
# ===============猜數字遊戲=================:
#
# 再小一點
# 您猜了 1 次
#
# 再小一點
# 您猜了 2 次
#
# 再小一點
# 您猜了 3 次
#
# 再大一點
# 您猜了 4 次
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       6 print(target)
#       7 print("===============猜數字遊戲=================:\n")
#       8 while(True):
#       9     count += 1
# ---> 10     keyin = int(input("猜數字範圍{0}~{1}: ".format(min, max)))
#      11     if(keyin >=min and keyin <= max):
#      12         if(keyin == target):
#      13             print("賓果!猜對了, 答案是:", target)
#
# File ~/Documents/github/test_0823_A/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
# ...
