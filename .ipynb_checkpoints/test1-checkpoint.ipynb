# %%
x =7
print (x ==5)
print (x ==7)
print (5 < x)
# Out:
# False
# True
# True

# %%
print('hello world')
# Out:
# hello world

# %%
a =13
if a !=12 :
    print ('不等於12')
else:
    print ('等於12')
# Out:
# 不等於12

# %%
password = input ("input password:")
if password =="1234" :
    print ("Weldome")
else:
    print ("password wrong \n please input again")
# Out:
# input password: 1234
# weldome

# %%
furry = False
small = True
if furry :
    if small :
        print("it's cat")
    else:
        print("it's bear")
else :
    if small :
        print("it's another aninomal")
# Out:
# it's another aninomal
